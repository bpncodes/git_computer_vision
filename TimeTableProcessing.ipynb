# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Capture.PNG',0)

# %%
def show(img):
    yo = plt.figure(figsize=(20,20))
    a = yo.add_subplot(111)
    a.imshow(img, cmap='gray')

# %%
im.shape
# Out:
# (548, 1300)

# %%
show(im)

# %%
show(img)

# %%
r, bin = cv2.threshold(img,120,255,cv2.THRESH_TOZERO)
a = cv2.imwrite('time1.jpg', gauss)

# %%
gauss = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2 )
ret, binary = cv2.threshold(img, 125,255, cv2.THRESH_TOZERO)
image = cv2.addWeighted(gauss, 0.5, binary, 0.5, 0)

# %%
cv2.imwrite('time2.jpg', image)
# Out:
# True
